# %%
from glob import glob
import pandas as pd

fnames = glob('completions_data/2002-2007/*.csv')
all_df = []
year = 2002
for fname in fnames: 
    df = pd.read_csv(fname)
    df.columns = df.columns.str.upper()
    df.columns = [x.strip() for x in df.columns]
    df  = df[df['AWLEVEL'] == 9] #AW level 9 for doctor's degree
    df  = df[df['CRACE24']>0]
    df0 = df[(df['CIPCODE'] == 99)]
    df1 = df[(df['CIPCODE'] >=11.0101) & (df['CIPCODE'] < 12)]
    

    df0['Year'] = year
    df1['Year'] = year
    df0 = df0[['UNITID','MAJORNUM', 'CIPCODE', 'CRACE24','CRACE18','CRACE21','CRACE16','Year','AWLEVEL']]
    df1 = df1[['UNITID','MAJORNUM', 'CIPCODE', 'CRACE24','CRACE18','CRACE21','CRACE16','Year','AWLEVEL']]
    year+=1
    all_df.append(df0)
    all_df.append(df1)
bigdf0 = pd.concat(all_df)
bigdf0 = bigdf0.rename(columns={'UNITID':'Unit Id'})
bigdf0 = bigdf0.rename(columns={'CIPCODE':'Degrees'})
bigdf0 = bigdf0.rename(columns={'CRACE24':'Grand total students'})
bigdf0 = bigdf0.rename(columns={'CRACE18':'Black total students'})
bigdf0 = bigdf0.rename(columns={'CRACE21':'Hispanic total students'})
bigdf0 = bigdf0.rename(columns={'CRACE16':'Grand total women students'})
# Out:
# /var/folders/c4/qy50h61x069887_6qkp4f7880000gp/T/ipykernel_87314/3254743305.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df0['Year'] = year
# /var/folders/c4/qy50h61x069887_6qkp4f7880000gp/T/ipykernel_87314/3254743305.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Year'] = year
# /var/folders/c4/qy50h61x069887_6qkp4f7880000gp/T/ipykernel_87314/3254743305.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df0['Year'] = year
# /var/folders/c4/qy50h61x069887_6qkp4f7880000gp/T/ipykernel_87314/3254743305.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Year'] = year
# /var/folders/c4/qy50h61x069887_6qkp4f7880000gp/T/ipykernel_87314/3254743305.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df0['Year'] = year
# /var/folders/c4/qy50h61x069887_6qkp4f7880000gp/T/ipykernel_87314/3254743305.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Year'] = year
# /var/folders/c4/qy50h61x069887_6qkp4f7880000gp/T/ipykernel_87314/3254743305.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df0['Year'] = year
# /var/folders/c4/qy50h61x069887_6qkp4f7880000gp/T/ipykernel_87314/3254743305.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Year'] = year
# /var/folders/c4/qy50h61x069887_6qkp4f7880000gp/T/ipykernel_87314/3254743305.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df0['Year'] = year
# /var/folders/c4/qy50h61x069887_6qkp4f7880000gp/T/ipykernel_87314/3254743305.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Year'] = year
# /var/folders/c4/qy50h61x069887_6qkp4f7880000gp/T/ipykernel_87314/3254743305.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df0['Year'] = year
# /var/folders/c4/qy50h61x069887_6qkp4f7880000gp/T/ipykernel_87314/3254743305.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Year'] = year

# %%
"""
2008, 2009, 2010
# 31680	UNITID	Unique identification number of the institution
#  MAJORNUM	First or Second Major
# 31000	CIPCODE	11.0101	Computer and Information Sciences, General	
# 31000	CIPCODE	11.9999	Computer and Information Sciences and Support Services, Other	
# 31130	CTOTALT	Awards/degrees to all race/ethnicities and both genders
# 31640	DVCBKT	"Awards/degrees to Black or African American men and women.
# 31655	DVCHST	"Awards/degrees to Hispanic or Latino/Hispanic men and women.
# 31090	CTOTALW	N	6	Cont		Grand total women
"""

from glob import glob
import pandas as pd
fnames = glob('completions_data/2008-2010/*.csv')
all_df = []
year = 2008
for fname in fnames: 
    df = pd.read_csv(fname)
    df.columns = df.columns.str.upper()
    df.columns = [x.strip() for x in df.columns]
    df  = df[(df['AWLEVEL'] > 16) & (df['AWLEVEL'] < 20)] #AW level 17 or higher for doctor's degree
    df  = df[df['CTOTALT']>0]
    df0 = df[(df['CIPCODE'] == 99)]
    df1 = df[(df['CIPCODE'] >=11.0101)]
    df1 = df1[(df1['CIPCODE'] < 12)]

    df0['Year'] = year
    df1['Year'] = year
    df0 = df0[['UNITID','MAJORNUM', 'CIPCODE', 'CTOTALT','DVCBKT','DVCHST','CTOTALW','Year','AWLEVEL']]
    df1 = df1[['UNITID','MAJORNUM', 'CIPCODE', 'CTOTALT','DVCBKT','DVCHST','CTOTALW','Year','AWLEVEL']]
    year+=1
    all_df.append(df0)
    all_df.append(df1)
bigdf1 = pd.concat(all_df)
bigdf1 = bigdf1.rename(columns={'UNITID':'Unit Id'})
bigdf1 = bigdf1.rename(columns={'CIPCODE':'Degrees'})
bigdf1 = bigdf1.rename(columns={'CTOTALT':'Grand total students'})
bigdf1 = bigdf1.rename(columns={'DVCBKT':'Black total students'})
bigdf1 = bigdf1.rename(columns={'DVCHST':'Hispanic total students'})
bigdf1 = bigdf1.rename(columns={'CTOTALW':'Grand total women students'})
# Out:
# /var/folders/c4/qy50h61x069887_6qkp4f7880000gp/T/ipykernel_87314/1295421880.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df0['Year'] = year
# /var/folders/c4/qy50h61x069887_6qkp4f7880000gp/T/ipykernel_87314/1295421880.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df0['Year'] = year
# /var/folders/c4/qy50h61x069887_6qkp4f7880000gp/T/ipykernel_87314/1295421880.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df0['Year'] = year

# %%
from glob import glob
import pandas as pd
fnames = glob('completions_data/2011-2022/*.csv')

all_df = []
year = 2011
for fname in fnames: 
    df  = pd.read_csv(fname)
    df.columns = df.columns.str.upper()
    df.columns = [x.strip() for x in df.columns]
    df  = df[(df['AWLEVEL'] > 16) & (df['AWLEVEL'] < 20)] #AW level 17 or higher for doctor's degree
    df  = df[df['CTOTALT']>0]
    df0 = df[(df['CIPCODE'] == 99)]
    df1 = df[(df['CIPCODE'] >=11.0101)]
    df1 = df1[(df1['CIPCODE'] < 12)]

    df0['Year'] = year
    df1['Year'] = year
    df0 = df0[['UNITID','MAJORNUM', 'CIPCODE', 'CTOTALT','CBKAAT','CHISPT','CTOTALW','Year','AWLEVEL']]
    df1 = df1[['UNITID','MAJORNUM', 'CIPCODE', 'CTOTALT','CBKAAT','CHISPT','CTOTALW','Year','AWLEVEL']]
    year+=1
    all_df.append(df0)
    all_df.append(df1)
bigdf2 = pd.concat(all_df)
bigdf2 = bigdf2.rename(columns={'UNITID':'Unit Id'})
bigdf2 = bigdf2.rename(columns={'CIPCODE':'Degrees'})
bigdf2 = bigdf2.rename(columns={'CTOTALT':'Grand total students'})
bigdf2 = bigdf2.rename(columns={'CBKAAT':'Black total students'})
bigdf2 = bigdf2.rename(columns={'CHISPT':'Hispanic total students'})
bigdf2 = bigdf2.rename(columns={'CTOTALW':'Grand total women students'})
# Out:
# /var/folders/c4/qy50h61x069887_6qkp4f7880000gp/T/ipykernel_87314/3729422388.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df0['Year'] = year
# /var/folders/c4/qy50h61x069887_6qkp4f7880000gp/T/ipykernel_87314/3729422388.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df0['Year'] = year
# /var/folders/c4/qy50h61x069887_6qkp4f7880000gp/T/ipykernel_87314/3729422388.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df0['Year'] = year
# /var/folders/c4/qy50h61x069887_6qkp4f7880000gp/T/ipykernel_87314/3729422388.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df0['Year'] = year
# /var/folders/c4/qy50h61x069887_6qkp4f7880000gp/T/ipykernel_87314/3729422388.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df0['Year'] = year
# /var/folders/c4/qy50h61x069887_6qkp4f7880000gp/T/ipykernel_87314/3729422388.py:8: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df  = pd.read_csv(fname)
# /var/folders/c4/qy50h61x069887_6qkp4f7880000gp/T/ipykernel_87314/3729422388.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df0['Year'] = year
# /var/folders/c4/qy50h61x069887_6qkp4f7880000gp/T/ipykernel_87314/3729422388.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df0['Year'] = year
# /var/folders/c4/qy50h61x069887_6qkp4f7880000gp/T/ipykernel_87314/3729422388.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df0['Year'] = year
# /var/folders/c4/qy50h61x069887_6qkp4f7880000gp/T/ipykernel_87314/3729422388.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df0['Year'] = year
# /var/folders/c4/qy50h61x069887_6qkp4f7880000gp/T/ipykernel_87314/3729422388.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df0['Year'] = year
# /var/folders/c4/qy50h61x069887_6qkp4f7880000gp/T/ipykernel_87314/3729422388.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df0['Year'] = year
# /var/folders/c4/qy50h61x069887_6qkp4f7880000gp/T/ipykernel_87314/3729422388.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df0['Year'] = year

# %%
stud_df = pd.concat([bigdf0, bigdf1, bigdf2])

# %%
unique_unis = None
for year in range(2005, 2023): 
    year_data = stud_df[stud_df['Year']==year]
    if year == 2005: 
        unique_unis = set(year_data['Unit Id'].unique())
    else: 
        unique_unis_year = set(year_data['Unit Id'].unique())
        unique_unis = unique_unis.intersection(unique_unis_year)

# %%
len(unique_unis)
# Out:
# 110

# %%
stud_df = stud_df[stud_df['Unit Id'].apply(lambda x: x in unique_unis)]

# %%
total = stud_df[stud_df['Degrees'] == 99].groupby(['Unit Id','Year',]).sum()
total = total[['Grand total students', 'Black total students', 'Hispanic total students', 'Grand total women students']]
total=total.rename(columns={'Grand total students':'grand_phd_total', 'Black total students': 'black_phd_total','Hispanic total students':'hispanic_phd_total','Grand total women students':'women_phd_total'})
cs = stud_df[stud_df['Degrees'] != 99].groupby(['Unit Id','Year']).sum()
total_cs = cs[['Grand total students', 'Black total students', 'Hispanic total students', 'Grand total women students']]
total_cs=total_cs.rename(columns={'Grand total students':'total_phd_cs', 'Black total students': 'black_phd_cs','Hispanic total students':'hispanic_phd_cs','Grand total women students':'women_phd_cs'})
total_cs
# Out:
#               total_phd_cs  black_phd_cs  hispanic_phd_cs  women_phd_cs
# Unit Id Year
# 104151  2002             7             0                1             2
#         2003             6             0                0             3
#         2004             8             0                0             0
#         2005            15             0                0             3
#         2006            21             0                0             4
# ...                    ...           ...              ...           ...
# 240727  2017             1             0                0             0
#         2018             2             0                0             2
#         2020             2             0                0             0
#         2021             2             0                0             0
#         2022             2             0                1             0
#
# [610 rows x 4 columns]

# %%
all_stud = pd.concat([total,total_cs], axis =1)
all_stud = all_stud.reset_index()
all_stud
full = []
inst = pd.read_csv('data/hd2020.csv', encoding='cp1252')
inst = inst[['UNITID','INSTNM','CITY','STABBR','INSTSIZE','LONGITUD','LATITUDE','OBEREG', 'CARNEGIE']]
inst = inst.rename(columns={'UNITID':'Unit Id'})
merged = pd.merge(inst, all_stud, on='Unit Id')
merged = merged.dropna()
merged[merged['INSTNM']=='Harvard University']
merged.to_csv('all_studphd_inst.csv')

# %%
all_stud.isna().sum() / len(all_stud)
# Out:
# Unit Id               0.000000
# Year                  0.000000
# grand_phd_total       0.000000
# black_phd_total       0.000000
# hispanic_phd_total    0.000000
# women_phd_total       0.000000
# total_phd_cs          0.733741
# black_phd_cs          0.733741
# hispanic_phd_cs       0.733741
# women_phd_cs          0.733741
# dtype: float64

# %%
from matplotlib import pyplot as plt
a_stud.groupby('Year')['total_phd_cs'].sum().plot()
plt.twinx()
a_stud.groupby('Year')['grand_phd_total'].sum().plot(color='orange')
# Out:
# <Axes: xlabel='Year'>

# %%
a_stud.groupby('Year').apply(lambda x: len(x['Unit Id'].unique()))
# Out:
# /var/folders/c4/qy50h61x069887_6qkp4f7880000gp/T/ipykernel_87314/1676659880.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   a_stud.groupby('Year').apply(lambda x: len(x['Unit Id'].unique()))
# Year
# 2002    22
# 2003    22
# 2004    26
# 2005    26
# 2006    28
# 2007    28
# 2008    28
# 2009    28
# 2010    29
# 2011    33
# 2012    29
# 2013    31
# 2014    29
# 2015    28
# 2016    30
# 2017    30
# 2018    34
# 2019    33
# 2020    32
# 2021    31
# 2022    33
# dtype: int64

# %%
all_stud.head()
# Out:
#    Unit Id  Year  grand_phd_total  black_phd_total  hispanic_phd_total  \
# 0   100724  2004                5                4                   0
# 1   100724  2005                1                0                   0
# 2   100724  2006               12                4                   1
# 3   100724  2007               39               21                   0
# 4   100724  2008               54               29                   0
#
#    women_phd_total  total_phd_cs  black_phd_cs  hispanic_phd_cs  women_phd_cs
# 0                3           NaN           NaN              NaN           NaN
# 1                0           NaN           NaN              NaN           NaN
# 2                8           NaN           NaN              NaN           NaN
# 3               20           NaN           NaN              NaN           NaN
# 4               36           NaN           NaN              NaN           NaN
